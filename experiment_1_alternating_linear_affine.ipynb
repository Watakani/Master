# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import os

import numpy as np
import matplotlib.pyplot as plt

from NormalizingFlows.src.train import train_backward
from NormalizingFlows.src.scores import log_likelihood
from NormalizingFlows.src.utils import update_device, load_best_model, load_checkpoint_model

from NormalizingFlows.src.flows import *
from NormalizingFlows.src.data.density.toydata import ToyDataset

# %%
def set_visible_devices(*devices: int) -> None:
    '''Utility to set visible Cuda devices.

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.
    '''
    assert all([d >= 0 for d in devices]), f"Not all devices are CUDA devices!"
    os.environ['CUDA_VISIBLE_DEVICES'] = ",".join([str(i) for i in devices])
    

def set_devices(*devices: int):
    '''Utility to set Cuda device(s).

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.

    Returns
    -------
    torch.device or List[torch.device] of currently available CUDA devices.
    '''
    assert len(devices) > 0, f'Device list is empty, no devices set.'
    if len(devices) == 1:
        if devices[0] >= 0:
            set_visible_devices(devices[0])
            return torch.device(0)
        else:
            return torch.device('cpu')

    else:
        set_visible_devices(*devices)
        return [torch.device(i) for i in range(len(devices))]

# %%
device = set_devices(0) #torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device_cpu = torch.device("cpu")

# %%
dim_input = 25
dataset = ToyDataset(dim_input=dim_input, samples=10000)

dim_input = dataset.dim_input
num_trans = 6 #Must be even
perm_types = ['identity', 'alternate','random']
dim_hidden = [100,100,100]
flows = {}
flow_forward = False


epochs = 15
batch_size = 32
num_exp = 5

# %%
# #Linear and mean field

# transformations = create_constant_trans(num_trans, dim_input, flow_forward)
# mean_field = create_flows_with_identity(dim_input, transformations, flow_forward) 
# name = 'Mean field'
# flows.append(mean_field), names.append(name)

# transformations = create_linear_bias_trans(num_trans, dim_input, flow_forward)
# linear = create_flows_with_identity(dim_input, transformations, flow_forward)
# name = 'Linear'
# flows.append(linear), names.append(name);

# %%
# #Affine flows with two block

# name = 'Affine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine coupling alternating'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_coup_alt]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'Affine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Affine flows with AR

# name = 'Affine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with coupling

# name = 'PiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_coup_id]
#     flows[name][-1].name = f'{name} {i}'
    

# name = 'PiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with AR

# name = 'PiecewiseAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_ar_id]
#     flows[name][-1].name = f'{name} {i}'


# name = 'PiecewiseAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with twoblock

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with AR

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with twoblock

# name = 'ContinuousPiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [conpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [conpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [conpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with AR

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'ContinuousPiecewiseAffine AR identity'
# flows.append(conpiec_ar_iden), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
# name = 'ContinuousPiecewiseAffine AR alternate'
# flows.append(conpiec_ar_alt), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'ContinuousPiecewiseAffine AR random'
# flows.append(conpiec_ar_rand), names.append(name);

# %%
# #ContinuousPiecewiseAffine with twoblock
# name = 'ContinuousPiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [affconpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'ContinuousPiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [affconpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [affconpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewiseAffine with AR
# name = 'ContinuousPiecewiseAffineAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [affconpiec_ar_iden]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [affconpiec_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [affconpiec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating Piecewise Affine with twoblock

# name = 'Alternating Affin_PiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
#     afpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [afpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating Piecewise Affine with AR

# name = 'Alternating Affin_PiecewiseAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
#     afpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [afpiec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
#Alternating with Linear layer and Affine

name = 'Alternating Linear_Affine coupling identity'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
    linaff_coup_iden = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
    flows[name] += [linaff_coup_iden]
    flows[name][-1].name = f'{name} {i}'
    
name = 'Alternating Linear_Affine coupling random'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
    linaff_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [linaff_coup_rand]
    flows[name][-1].name = f'{name} {i}'
    
name = 'Alternating Linear_Affine AR identity'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
    linaff_ar_iden = create_flows_with_alt_identity_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
    flows[name] += [linaff_ar_iden]
    flows[name][-1].name = f'{name} {i}'
    
name = 'Alternating Linear_Affine AR random'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
    linaff_ar_rand = create_flows_with_alt_identity_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [linaff_ar_rand]
    flows[name][-1].name = f'{name} {i}'

# %%
# #Various Alternating Linear and Conditioner transformation

# transformations = create_alt_linear_piecewise_trans(num_trans, dim_input, flow_forward)
# linpiece_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_PiecewiseAffine coupling random'
# flows.append(linpiece_coup_rand), names.append(name)

# transformations = create_alt_linear_continuous_trans(num_trans, dim_input, flow_forward)
# lincont_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_ContinuousPiece coupling random'
# flows.append(lincont_coup_rand), names.append(name)

# transformations = create_alt_linear_affinepiecewise_trans(num_trans, dim_input, flow_forward)
# linaffpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_AffinePiece coupling random'
# flows.append(linaffpiec_coup_rand), names.append(name)

# transformations = create_alt_linear_affinecontinuous_trans(num_trans, dim_input, flow_forward)
# linaffcont_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_AffineContinuous coupling random'
# flows.append(linaffcont_coup_rand), names.append(name);

# %%
losses = {n: [] for n in flows.keys()}
optimizers = {n: [] for n in flows.keys()}

for flowname in flows.keys():
    for j in range(num_exp):
        # Initialize flow
        flow = flows[flowname][j]
        update_device(device, flow, dataset)

        # Initialize optimizer
        optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-4, weight_decay=1e-2)
        optimizers[flowname].append(optimizer)
        
        # Train and append losses
        losses[flowname].append(
            train_backward(
                flow, 
                dataset.get_training_data(), 
                optimizer, 
                epochs - 7, 
                batch_size, 
                print_n=200, 
                save_checkpoint=True, 
                burn_in=-1
            )
        )

        # Move flow to CPU
        update_device(device_cpu, flow, dataset)
# Out:
# Finished training. Loss for last epoch Alternating Linear_Affine AR random 4:     46.94851

# %%
best_flows = {n:[] for n in flows.keys()}
for flowname in flows.keys():
    for i in range(num_exp):
        best_flows[flowname].append(load_best_model(flows[flowname][i]))

# %%
log_scale = True
from_iter = 50 * batch_size

fig, ax = plt.subplots(2, len(flows), figsize=(12,6))
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        ax[0,j].plot(losses[flowname][i], label=f'exp{i}', alpha=0.8)
        ax[0,j].set_title(f'{flowname}')
        if log_scale:
            ax[0, j].set_yscale('log')
        ax[0, j].legend()
        
log_scale = True
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        x = np.arange(len(losses[flowname][i]))
        ax[1,j].plot(x[from_iter:], losses[flowname][i][from_iter:], label=f'exp{i}', alpha=0.8)
        if log_scale:
            ax[1, j].set_yscale('log')
        ax[1, j].legend()
    
plt.tight_layout()

# %%
flow_lh_results = {
    'train': {n:[] for n in flows}, 
    'test': {n:[] for n in flows}, 
    'sample': {n:[] for n in flows},
}
cur_res = 'train'

print('Results based on training data:' + '\n')

# Function for CI
def mean_confidence_interval(data, confidence=0.95):
    import scipy.stats
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, h
 

train_data = dataset.get_training_data()
mean_target = torch.mean(dataset.evaluate(train_data.to(device))).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(train_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on training data:
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 0: [-46.530827]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.05934906]
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 1: [-46.539528]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.06805038]
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 2: [-46.656525]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.18504715]
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 3: [-46.548225]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.07674789]
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 4: [-46.565132]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.09365463]
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine coupling identity -- Mean LogLH Bootstrap: -46.5680 ±  0.0634
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 0: [-46.524136]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.05265808]
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 1: [-46.545944]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.07446671]
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 2: [-46.45291]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.01856613]
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 3: [-46.567608]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.09613037]
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 4: [-46.497456]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.02597809]
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine coupling random -- Mean LogLH Bootstrap: -46.5176 ±  0.0553
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 0: [-47.027493]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.556015]
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 1: [-47.025787]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.55430984]
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 2: [-46.95627]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.4847908]
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 3: [-46.873405]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.40192795]
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 4: [-46.825558]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.3540802]
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine AR identity -- Mean LogLH Bootstrap: -46.9417 ±  0.1124
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine AR random 0: [-46.90915]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.43767166]
#
# Mean loglikelihood for Alternating Linear_Affine AR random 1: [-46.8273]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.35582352]
#
# Mean loglikelihood for Alternating Linear_Affine AR random 2: [-46.900562]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.42908478]
#
# Mean loglikelihood for Alternating Linear_Affine AR random 3: [-46.839985]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.3685074]
#
# Mean loglikelihood for Alternating Linear_Affine AR random 4: [-46.903385]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.43190765]
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine AR random -- Mean LogLH Bootstrap: -46.8761 ±  0.0486
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -46.47147750854492

# %%
print('Results based on test data' + '\n')
cur_res = 'test' 

test_data = dataset.get_test_data()
mean_target = torch.mean(dataset.evaluate(test_data)).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(test_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))

# for flow in best_flows:
#     log_lik, mean = log_likelihood(test_data, flow)
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
    

# print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on test data
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 0: [-46.793205]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.3362198]
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 1: [-46.705704]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.24871826]
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 2: [-46.875454]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.41846848]
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 3: [-46.78861]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.33162308]
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 4: [-46.785706]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.3287201]
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine coupling identity -- Mean LogLH Bootstrap: -46.7897 ±  0.0746
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 0: [-46.763435]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.3064499]
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 1: [-46.70283]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.2458458]
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 2: [-46.711033]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.2540474]
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 3: [-46.765945]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.30895996]
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 4: [-46.732582]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.27559662]
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine coupling random -- Mean LogLH Bootstrap: -46.7352 ±  0.0361
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 0: [-47.00542]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.5484352]
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 1: [-47.052628]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.5956421]
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 2: [-47.012135]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.5551491]
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 3: [-46.846447]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.38946152]
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 4: [-46.796185]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.33919907]
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine AR identity -- Mean LogLH Bootstrap: -46.9426 ±  0.1410
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine AR random 0: [-46.966408]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.5094223]
#
# Mean loglikelihood for Alternating Linear_Affine AR random 1: [-46.847725]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.39073944]
#
# Mean loglikelihood for Alternating Linear_Affine AR random 2: [-46.901947]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.44496155]
#
# Mean loglikelihood for Alternating Linear_Affine AR random 3: [-46.84996]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.39297485]
#
# Mean loglikelihood for Alternating Linear_Affine AR random 4: [-46.952267]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.49528122]
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine AR random -- Mean LogLH Bootstrap: -46.9037 ±  0.0689
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -46.45698547363281

# %%
print('Results based on new sample from each flow:' + '\n')
cur_res = 'sample'

for flow in best_flows:
    for i in range(num_exp):
        with torch.no_grad():
            sample, log_prob = flows[flow][i].sample(800)
            sample_last = sample[-1]

        mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
        log_lik, mean = log_likelihood(sample_last, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print("Mean loglikelihood with actual distribution: {}".format(mean_target))   
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()


# for flow in best_flows:
#     with torch.no_grad():
#         sample, log_prob = flow.sample(800)
#         sample_last = sample[-1]

#     #sample_last.clip_(-7, 7)
#     mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
#     log_lik, mean = log_likelihood(sample_last, flow)

#     print('Check for NANs: ', torch.isnan(sample_last).any().item())
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))    
#     print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on new sample from each flow:
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 0: [-46.945812]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.27778625]
# Mean loglikelihood with actual distribution: -47.22359848022461
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 1: [-46.707874]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.28979492]
# Mean loglikelihood with actual distribution: -46.9976692199707
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 2: [-47.034435]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.34537125]
# Mean loglikelihood with actual distribution: -47.37980651855469
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 3: [-46.689228]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.252388]
# Mean loglikelihood with actual distribution: -46.94161605834961
#
# Mean loglikelihood for Alternating Linear_Affine coupling identity 4: [-46.34994]
# Difference between target and Alternating Linear_Affine coupling identity mean loglikelihood: [0.32579422]
# Mean loglikelihood with actual distribution: -46.67573547363281
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine coupling identity -- Mean LogLH Bootstrap: -46.7455 ±  0.3312
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 0: [-46.741512]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.27392197]
# Mean loglikelihood with actual distribution: -47.01543426513672
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 1: [-47.073975]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.28676605]
# Mean loglikelihood with actual distribution: -47.360740661621094
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 2: [-46.592545]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.28524017]
# Mean loglikelihood with actual distribution: -46.877784729003906
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 3: [-46.955658]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.33225632]
# Mean loglikelihood with actual distribution: -47.28791427612305
#
# Mean loglikelihood for Alternating Linear_Affine coupling random 4: [-46.19383]
# Difference between target and Alternating Linear_Affine coupling random mean loglikelihood: [0.23521423]
# Mean loglikelihood with actual distribution: -46.42904281616211
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine coupling random -- Mean LogLH Bootstrap: -46.7115 ±  0.4274
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 0: [-47.34827]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.670208]
# Mean loglikelihood with actual distribution: -48.01847839355469
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 1: [-47.604748]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.7101555]
# Mean loglikelihood with actual distribution: -48.314903259277344
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 2: [-47.940483]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.5493164]
# Mean loglikelihood with actual distribution: -48.48979949951172
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 3: [-47.414326]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.48953247]
# Mean loglikelihood with actual distribution: -47.90385818481445
#
# Mean loglikelihood for Alternating Linear_Affine AR identity 4: [-46.974106]
# Difference between target and Alternating Linear_Affine AR identity mean loglikelihood: [0.44174194]
# Mean loglikelihood with actual distribution: -47.41584777832031
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine AR identity -- Mean LogLH Bootstrap: -47.4564 ±  0.4401
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_Affine AR random 0: [-47.178883]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.48386765]
# Mean loglikelihood with actual distribution: -47.662750244140625
#
# Mean loglikelihood for Alternating Linear_Affine AR random 1: [-46.97958]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.39367676]
# Mean loglikelihood with actual distribution: -47.37325668334961
#
# Mean loglikelihood for Alternating Linear_Affine AR random 2: [-47.61701]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.5215645]
# Mean loglikelihood with actual distribution: -48.138572692871094
#
# Mean loglikelihood for Alternating Linear_Affine AR random 3: [-47.234676]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.5189285]
# Mean loglikelihood with actual distribution: -47.753604888916016
#
# Mean loglikelihood for Alternating Linear_Affine AR random 4: [-47.553364]
# Difference between target and Alternating Linear_Affine AR random mean loglikelihood: [0.612072]
# Mean loglikelihood with actual distribution: -48.165435791015625
#
# ---------------------------------------------------------------------------
# Alternating Linear_Affine AR random -- Mean LogLH Bootstrap: -47.3127 ±  0.3317
# ---------------------------------------------------------------------------
