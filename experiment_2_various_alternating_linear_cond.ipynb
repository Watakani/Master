# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import os

import numpy as np
import matplotlib.pyplot as plt

from NormalizingFlows.src.train import train_backward
from NormalizingFlows.src.scores import log_likelihood
from NormalizingFlows.src.utils import update_device, load_best_model, load_checkpoint_model

from NormalizingFlows.src.flows import *
from NormalizingFlows.src.data.density.toydata import ToyDataset

# %%
def set_visible_devices(*devices: int) -> None:
    '''Utility to set visible Cuda devices.

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.
    '''
    assert all([d >= 0 for d in devices]), f"Not all devices are CUDA devices!"
    os.environ['CUDA_VISIBLE_DEVICES'] = ",".join([str(i) for i in devices])
    

def set_devices(*devices: int):
    '''Utility to set Cuda device(s).

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.

    Returns
    -------
    torch.device or List[torch.device] of currently available CUDA devices.
    '''
    assert len(devices) > 0, f'Device list is empty, no devices set.'
    if len(devices) == 1:
        if devices[0] >= 0:
            set_visible_devices(devices[0])
            return torch.device(0)
        else:
            return torch.device('cpu')

    else:
        set_visible_devices(*devices)
        return [torch.device(i) for i in range(len(devices))]

# %%
device = set_devices(1) #torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device_cpu = torch.device("cpu")

# %%
np.random.seed(10290)
dim_input = 50
distr_params = torch.FloatTensor(np.random.uniform(0.5,3,(dim_input,)))
target_distr = torch.distributions.independent.Independent(
            torch.distributions.exponential.Exponential(distr_params),1)
dataset = ToyDataset(dim_input=dim_input,data_distr=target_distr, samples=10000)

dim_input = dataset.dim_input
num_trans = 8 #Must be even
perm_types = ['identity', 'alternate','random']
dim_hidden = [200,200,200]
flows = {}
flow_forward = False


epochs = 25
batch_size = 32
num_exp = 5

# %%
# #Linear and mean field

# transformations = create_constant_trans(num_trans, dim_input, flow_forward)
# mean_field = create_flows_with_identity(dim_input, transformations, flow_forward) 
# name = 'Mean field'
# flows.append(mean_field), names.append(name)

# transformations = create_linear_bias_trans(num_trans, dim_input, flow_forward)
# linear = create_flows_with_identity(dim_input, transformations, flow_forward)
# name = 'Linear'
# flows.append(linear), names.append(name);

# %%
# #Affine flows with two block

# name = 'Affine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine coupling alternating'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_coup_alt]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'Affine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Affine flows with AR

# name = 'Affine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with coupling

# name = 'PiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_coup_id]
#     flows[name][-1].name = f'{name} {i}'
    

# name = 'PiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with AR

# name = 'PiecewiseAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_ar_id]
#     flows[name][-1].name = f'{name} {i}'


# name = 'PiecewiseAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with twoblock

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with AR

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with twoblock

# name = 'ContinuousPiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [conpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [conpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [conpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with AR

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'ContinuousPiecewiseAffine AR identity'
# flows.append(conpiec_ar_iden), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
# name = 'ContinuousPiecewiseAffine AR alternate'
# flows.append(conpiec_ar_alt), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'ContinuousPiecewiseAffine AR random'
# flows.append(conpiec_ar_rand), names.append(name);

# %%
# #ContinuousPiecewiseAffine with twoblock
# name = 'ContinuousPiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [affconpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'ContinuousPiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [affconpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [affconpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewiseAffine with AR
# name = 'ContinuousPiecewiseAffineAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [affconpiec_ar_iden]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [affconpiec_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [affconpiec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating Piecewise Affine with twoblock

# name = 'Alternating Affin_PiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
#     afpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [afpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating Piecewise Affine with AR

# name = 'Alternating Affin_PiecewiseAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
#     afpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [afpiec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating with Linear layer and Affine

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'Alternating Linear_Affine coupling identity'
# flows.append(linaff_coup_iden), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_Affine coupling random'
# flows.append(linaff_coup_rand), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'Alternating Linear_Affine AR identity'
# flows.append(linaff_ar_iden), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_Affine AR random'
# flows.append(linaff_ar_rand), names.append(name);

# %%
#Various Alternating Linear and Conditioner transformation

name = 'Alternating Linear_PiecewiseAffine coupling random'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_piecewise_trans(num_trans, dim_input, flow_forward)
    linpiece_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [linpiece_coup_rand]
    flows[name][-1].name = f'{name} {i}'

name = 'Alternating Linear_ContinuousPiece coupling random'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_continuous_trans(num_trans, dim_input, flow_forward)
    lincont_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [lincont_coup_rand]
    flows[name][-1].name = f'{name} {i}'

name = 'Alternating Linear_AffinePiece coupling random'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_affinepiecewise_trans(num_trans, dim_input, flow_forward)
    linaffpiec_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [linaffpiec_coup_rand]
    flows[name][-1].name = f'{name} {i}'

name = 'Alternating Linear_AffineContinuous coupling random'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_affinecontinuous_trans(num_trans, dim_input, flow_forward)
    linaffcont_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [linaffcont_coup_rand]
    flows[name][-1].name = f'{name} {i}'

# %%
losses = {n: [] for n in flows.keys()}
optimizers = {n: [] for n in flows.keys()}

for flowname in flows.keys():
    for j in range(num_exp):
        # Initialize flow
        flow = flows[flowname][j]
        update_device(device, flow, dataset)

        # Initialize optimizer
        optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-4, weight_decay=1e-2)
        optimizers[flowname].append(optimizer)
        
        # Train and append losses
        losses[flowname].append(
            train_backward(
                flow, 
                dataset.get_training_data(), 
                optimizer, 
                epochs, 
                batch_size, 
                print_n=200, 
                save_checkpoint=True, 
                burn_in=-1
            )
        )

        # Move flow to CPU
        update_device(device_cpu, flow, dataset)
# Out:
# Finished training. Loss for last epoch Alternating Linear_AffineContinuous coupling random 4:     38.11917

# %%
best_flows = {n:[] for n in flows.keys()}
for flowname in flows.keys():
    for i in range(num_exp):
        best_flows[flowname].append(load_best_model(flows[flowname][i]))

# %%
log_scale = True
from_iter = 5000

fig, ax = plt.subplots(2, len(flows), figsize=(12,6))
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        ax[0,j].plot(losses[flowname][i], label=f'exp{i}', alpha=0.8)
        ax[0,j].set_title(f'{flowname}')
        if log_scale:
            ax[0, j].set_yscale('log')
        ax[0, j].legend()
        
log_scale = True
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        x = np.arange(len(losses[flowname][i]))
        ax[1,j].plot(x[from_iter:], losses[flowname][i][from_iter:], label=f'exp{i}', alpha=0.8)
        if log_scale:
            ax[1, j].set_yscale('log')
        ax[1, j].legend()
    
plt.tight_layout()

# %%
flow_lh_results = {
    'train': {n:[] for n in flows}, 
    'test': {n:[] for n in flows}, 
    'sample': {n:[] for n in flows},
}
cur_res = 'train'

print('Results based on training data:' + '\n')

# Function for CI
def mean_confidence_interval(data, confidence=0.95):
    import scipy.stats
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, h
 

train_data = dataset.get_training_data()
mean_target = torch.mean(dataset.evaluate(train_data.to(device))).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(train_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on training data:
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 0: [-58.99891]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [28.263577]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1: [-60.0746]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [29.339268]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 2: [-58.80179]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [28.066456]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 3: [-56.706566]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [25.971233]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 4: [-55.561226]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [24.825893]
#
# ---------------------------------------------------------------------------
# Alternating Linear_PiecewiseAffine coupling random -- Mean LogLH Bootstrap: -58.0286 ±  2.2862
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 0: [-40.37297]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [9.637638]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1: [-40.37409]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [9.638756]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 2: [-40.55537]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [9.820038]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 3: [-40.74011]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [10.004776]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 4: [-40.517807]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [9.7824745]
#
# ---------------------------------------------------------------------------
# Alternating Linear_ContinuousPiece coupling random -- Mean LogLH Bootstrap: -40.5121 ±  0.1886
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 0: [-44.04736]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [13.312027]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1: [-46.51328]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [15.777946]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 2: [-44.527855]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [13.792522]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 3: [-46.30389]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [15.568558]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 4: [-43.62074]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [12.8854065]
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffinePiece coupling random -- Mean LogLH Bootstrap: -45.0026 ±  1.6453
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 0: [-38.482265]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [7.746933]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1: [-38.027905]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [7.292572]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 2: [-37.18673]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [6.451397]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 3: [-37.177357]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [6.442024]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 4: [-37.48554]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [6.750206]
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffineContinuous coupling random -- Mean LogLH Bootstrap: -37.6720 ±  0.7073
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -30.735332489013672

# %%
print('Results based on test data' + '\n')
cur_res = 'test' 

test_data = dataset.get_test_data()
mean_target = torch.mean(dataset.evaluate(test_data)).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(test_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))

# for flow in best_flows:
#     log_lik, mean = log_likelihood(test_data, flow)
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
    

# print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on test data
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 0: [-59.91549]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [29.071236]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1: [-60.88076]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [30.036507]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 2: [-59.768353]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [28.924099]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 3: [-58.147736]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [27.303482]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 4: [-56.886593]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [26.04234]
#
# ---------------------------------------------------------------------------
# Alternating Linear_PiecewiseAffine coupling random -- Mean LogLH Bootstrap: -59.1198 ±  1.9717
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 0: [-45.1229]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [14.278645]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1: [-45.0962]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [14.2519455]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 2: [-44.955624]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [14.11137]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 3: [-45.272045]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [14.427792]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 4: [-44.858246]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [14.013992]
#
# ---------------------------------------------------------------------------
# Alternating Linear_ContinuousPiece coupling random -- Mean LogLH Bootstrap: -45.0610 ±  0.1981
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 0: [-46.669518]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [15.825264]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1: [-48.16014]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [17.315887]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 2: [-47.008957]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [16.164703]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 3: [-47.835304]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [16.99105]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 4: [-46.37286]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [15.528606]
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffinePiece coupling random -- Mean LogLH Bootstrap: -47.2094 ±  0.9471
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 0: [-43.770874]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [12.9266205]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1: [-43.99279]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [13.148537]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 2: [-43.944263]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [13.10001]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 3: [-44.192642]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [13.348389]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 4: [-44.69252]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [13.848267]
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffineContinuous coupling random -- Mean LogLH Bootstrap: -44.1186 ±  0.4399
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -30.844253540039062

# %%
print('Results based on new sample from each flow:' + '\n')
cur_res = 'sample'

for flow in best_flows:
    for i in range(num_exp):
        with torch.no_grad():
            sample, log_prob = flows[flow][i].sample(800)
            sample_last = sample[-1]
        
        eps = torch.finfo(torch.float).eps
        print(torch.sum(sample_last < eps).item())
        
        sample_last.clamp_min_(eps)

        mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
        log_lik, mean = log_likelihood(sample_last, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print("Mean loglikelihood with actual distribution: {}".format(mean_target))   
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()


# for flow in best_flows:
#     with torch.no_grad():
#         sample, log_prob = flow.sample(800)
#         sample_last = sample[-1]

#     #sample_last.clip_(-7, 7)
#     mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
#     log_lik, mean = log_likelihood(sample_last, flow)

#     print('Check for NANs: ', torch.isnan(sample_last).any().item())
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))    
#     print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on new sample from each flow:
#
# 9467
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 0: [-64.05632]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [16.819561]
# Mean loglikelihood with actual distribution: -47.236759185791016
#
# 9867
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1: [-65.25672]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [18.43671]
# Mean loglikelihood with actual distribution: -46.820011138916016
#
# 9442
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 2: [-65.59585]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [17.10527]
# Mean loglikelihood with actual distribution: -48.490577697753906
#
# 8508
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 3: [-62.813797]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [14.846157]
# Mean loglikelihood with actual distribution: -47.9676399230957
#
# 8482
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 4: [-60.740158]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random mean loglikelihood: [14.635998]
# Mean loglikelihood with actual distribution: -46.10416030883789
#
# ---------------------------------------------------------------------------
# Alternating Linear_PiecewiseAffine coupling random -- Mean LogLH Bootstrap: -63.6926 ±  2.4592
# ---------------------------------------------------------------------------
#
# 4462
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 0: [-38.2178]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [5.4329796]
# Mean loglikelihood with actual distribution: -32.784820556640625
#
# 4457
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1: [-37.872913]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [5.6686897]
# Mean loglikelihood with actual distribution: -32.2042236328125
#
# 4533
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 2: [-38.070683]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [6.0690765]
# Mean loglikelihood with actual distribution: -32.00160598754883
#
# 4564
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 3: [-38.342472]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [6.1437836]
# Mean loglikelihood with actual distribution: -32.19868850708008
#
# 4518
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 4: [-37.42767]
# Difference between target and Alternating Linear_ContinuousPiece coupling random mean loglikelihood: [5.867941]
# Mean loglikelihood with actual distribution: -31.559728622436523
#
# ---------------------------------------------------------------------------
# Alternating Linear_ContinuousPiece coupling random -- Mean LogLH Bootstrap: -37.9863 ±  0.4444
# ---------------------------------------------------------------------------
#
# 4997
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 0: [-41.01774]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [6.7458496]
# Mean loglikelihood with actual distribution: -34.271888732910156
#
# 5474
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1: [-42.633038]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [8.317818]
# Mean loglikelihood with actual distribution: -34.31521987915039
#
# 4738
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 2: [-40.323975]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [5.8704453]
# Mean loglikelihood with actual distribution: -34.453529357910156
#
# 5668
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 3: [-41.466812]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [9.226624]
# Mean loglikelihood with actual distribution: -32.24018859863281
#
# 5081
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 4: [-40.197212]
# Difference between target and Alternating Linear_AffinePiece coupling random mean loglikelihood: [7.193798]
# Mean loglikelihood with actual distribution: -33.003414154052734
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffinePiece coupling random -- Mean LogLH Bootstrap: -41.1278 ±  1.2268
# ---------------------------------------------------------------------------
#
# 4148
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 0: [-36.348343]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [4.834959]
# Mean loglikelihood with actual distribution: -31.513383865356445
#
# 3990
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1: [-36.01125]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [4.594635]
# Mean loglikelihood with actual distribution: -31.416614532470703
#
# 3581
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 2: [-35.307163]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [3.5876122]
# Mean loglikelihood with actual distribution: -31.71955108642578
#
# 3747
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 3: [-35.22538]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [3.6700287]
# Mean loglikelihood with actual distribution: -31.55535125732422
#
# 3799
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 4: [-35.380333]
# Difference between target and Alternating Linear_AffineContinuous coupling random mean loglikelihood: [3.9242115]
# Mean loglikelihood with actual distribution: -31.45612144470215
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffineContinuous coupling random -- Mean LogLH Bootstrap: -35.6545 ±  0.6173
# ---------------------------------------------------------------------------
