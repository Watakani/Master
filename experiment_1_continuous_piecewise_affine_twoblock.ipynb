# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import os

import numpy as np
import matplotlib.pyplot as plt

from NormalizingFlows.src.train import train_backward
from NormalizingFlows.src.scores import log_likelihood
from NormalizingFlows.src.utils import update_device, load_best_model, load_checkpoint_model

from NormalizingFlows.src.flows import *
from NormalizingFlows.src.data.density.toydata import ToyDataset

# %%
def set_visible_devices(*devices: int) -> None:
    '''Utility to set visible Cuda devices.

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.
    '''
    assert all([d >= 0 for d in devices]), f"Not all devices are CUDA devices!"
    os.environ['CUDA_VISIBLE_DEVICES'] = ",".join([str(i) for i in devices])
    

def set_devices(*devices: int):
    '''Utility to set Cuda device(s).

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.

    Returns
    -------
    torch.device or List[torch.device] of currently available CUDA devices.
    '''
    assert len(devices) > 0, f'Device list is empty, no devices set.'
    if len(devices) == 1:
        if devices[0] >= 0:
            set_visible_devices(devices[0])
            return torch.device(0)
        else:
            return torch.device('cpu')

    else:
        set_visible_devices(*devices)
        return [torch.device(i) for i in range(len(devices))]

# %%
device = set_devices(1) #torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device_cpu = torch.device("cpu")

# %%
dim_input = 25
dataset = ToyDataset(dim_input=dim_input, samples=10000)

dim_input = dataset.dim_input
num_trans = 6 #Must be even
perm_types = ['identity', 'alternate','random']
dim_hidden = [100,100,100]
flows = {}
flow_forward = False


epochs = 15
batch_size = 32
num_exp = 5

# %%
# #Linear and mean field

# transformations = create_constant_trans(num_trans, dim_input, flow_forward)
# mean_field = create_flows_with_identity(dim_input, transformations, flow_forward) 
# name = 'Mean field'
# flows.append(mean_field), names.append(name)

# transformations = create_linear_bias_trans(num_trans, dim_input, flow_forward)
# linear = create_flows_with_identity(dim_input, transformations, flow_forward)
# name = 'Linear'
# flows.append(linear), names.append(name);

# %%
# #Affine flows with two block

# name = 'Affine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine coupling alternating'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_coup_alt]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'Affine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Affine flows with AR

# name = 'Affine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with coupling

# name = 'PiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_coup_id]
#     flows[name][-1].name = f'{name} {i}'
    

# name = 'PiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with AR

# name = 'PiecewiseAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_ar_id]
#     flows[name][-1].name = f'{name} {i}'


# name = 'PiecewiseAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with twoblock

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with AR

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with twoblock

# name = 'ContinuousPiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [conpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [conpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [conpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with AR

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'ContinuousPiecewiseAffine AR identity'
# flows.append(conpiec_ar_iden), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
# name = 'ContinuousPiecewiseAffine AR alternate'
# flows.append(conpiec_ar_alt), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'ContinuousPiecewiseAffine AR random'
# flows.append(conpiec_ar_rand), names.append(name);

# %%
#ContinuousPiecewiseAffine with twoblock
name = 'ContinuousPiecewiseAffineAffine coupling identity 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_affinecontinuous_trans(num_trans, flow_forward)
    affconpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
    flows[name] += [affconpiec_coup_iden]
    flows[name][-1].name = f'{name} {i}'
    
name = 'ContinuousPiecewiseAffineAffine coupling alternate 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_affinecontinuous_trans(num_trans, flow_forward)
    affconpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
    flows[name] += [affconpiec_coup_alt]
    flows[name][-1].name = f'{name} {i}'

name = 'ContinuousPiecewiseAffineAffine coupling random 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_affinecontinuous_trans(num_trans, flow_forward)
    affconpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [affconpiec_coup_rand]
    flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewiseAffine with AR

# transformations = create_affinecontinuous_trans(num_trans, flow_forward)
# affconpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'ContinuousPiecewiseAffineAffine AR identity'
# flows.append(affconpiec_ar_iden), names.append(name)

# transformations = create_affinecontinuous_trans(num_trans, flow_forward)
# affconpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
# name = 'ContinuousPiecewiseAffineAffine AR alternate'
# flows.append(affconpiec_ar_alt), names.append(name)

# transformations = create_affinecontinuous_trans(num_trans, flow_forward)
# affconpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'ContinuousPiecewiseAffineAffine AR random'
# flows.append(affconpiec_ar_rand), names.append(name);

# %%
# #Alternating Piecewise Affine with twoblock

# transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
# afpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Affin_PiecewiseAffine coupling random'
# flows.append(afpiec_coup_rand), names.append(name);

# %%
# #Alternating Piecewise Affine with AR

# transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
# afpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Affin_PiecewiseAffine AR random'
# flows.append(afpiec_ar_rand), names.append(name);

# %%
# #Alternating with Linear layer and Affine

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'Alternating Linear_Affine coupling identity'
# flows.append(linaff_coup_iden), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_Affine coupling random'
# flows.append(linaff_coup_rand), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'Alternating Linear_Affine AR identity'
# flows.append(linaff_ar_iden), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_Affine AR random'
# flows.append(linaff_ar_rand), names.append(name);

# %%
# #Various Alternating Linear and Conditioner transformation

# transformations = create_alt_linear_piecewise_trans(num_trans, dim_input, flow_forward)
# linpiece_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_PiecewiseAffine coupling random'
# flows.append(linpiece_coup_rand), names.append(name)

# transformations = create_alt_linear_continuous_trans(num_trans, dim_input, flow_forward)
# lincont_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_ContinuousPiece coupling random'
# flows.append(lincont_coup_rand), names.append(name)

# transformations = create_alt_linear_affinepiecewise_trans(num_trans, dim_input, flow_forward)
# linaffpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_AffinePiece coupling random'
# flows.append(linaffpiec_coup_rand), names.append(name)

# transformations = create_alt_linear_affinecontinuous_trans(num_trans, dim_input, flow_forward)
# linaffcont_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_AffineContinuous coupling random'
# flows.append(linaffcont_coup_rand), names.append(name);

# %%
losses = {n: [] for n in flows.keys()}
optimizers = {n: [] for n in flows.keys()}

for flowname in flows.keys():
    for j in range(num_exp):
        # Initialize flow
        flow = flows[flowname][j]
        update_device(device, flow, dataset)

        # Initialize optimizer
        optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-4, weight_decay=1e-2)
        optimizers[flowname].append(optimizer)
        
        # Train and append losses
        losses[flowname].append(
            train_backward(
                flow, 
                dataset.get_training_data(), 
                optimizer, 
                epochs - 7, 
                batch_size, 
                print_n=200, 
                save_checkpoint=True, 
                burn_in=-1
            )
        )

        # Move flow to CPU
        update_device(device_cpu, flow, dataset)
# Out:
# Finished training. Loss for last epoch ContinuousPiecewiseAffineAffine coupling random 1 4:     46.60864

# %%
best_flows = {n:[] for n in flows.keys()}
for flowname in flows.keys():
    for i in range(num_exp):
        best_flows[flowname].append(load_best_model(flows[flowname][i]))

# %%
log_scale = True
from_iter = 50 * batch_size

fig, ax = plt.subplots(2, len(flows), figsize=(12,6))
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        ax[0,j].plot(losses[flowname][i], label=f'exp{i}', alpha=0.8)
        ax[0,j].set_title(f'{flowname}')
        if log_scale:
            ax[0, j].set_yscale('log')
        ax[0, j].legend()
        
log_scale = True
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        x = np.arange(len(losses[flowname][i]))
        ax[1,j].plot(x[from_iter:], losses[flowname][i][from_iter:], label=f'exp{i}', alpha=0.8)
        if log_scale:
            ax[1, j].set_yscale('log')
        ax[1, j].legend()
    
plt.tight_layout()

# %%
flow_lh_results = {
    'train': {n:[] for n in flows}, 
    'test': {n:[] for n in flows}, 
    'sample': {n:[] for n in flows},
}
cur_res = 'train'

print('Results based on training data:' + '\n')

# Function for CI
def mean_confidence_interval(data, confidence=0.95):
    import scipy.stats
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, h
 

train_data = dataset.get_training_data()
mean_target = torch.mean(dataset.evaluate(train_data.to(device))).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(train_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on training data:
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 0: [-46.550022]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.03259277]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 1: [-46.559025]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.04159546]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 2: [-46.61232]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.09489059]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 3: [-46.67119]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.153759]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 4: [-46.627586]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.11015701]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling identity 1 -- Mean LogLH Bootstrap: -46.6040 ±  0.0623
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 0: [-46.6407]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.12327194]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 1: [-46.563553]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.0461235]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 2: [-46.664974]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.14754486]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 3: [-46.591125]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.07369614]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 4: [-46.680935]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.16350555]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling alternate 1 -- Mean LogLH Bootstrap: -46.6283 ±  0.0616
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 0: [-46.54147]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.02404022]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 1: [-46.58586]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.06843185]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 2: [-46.52282]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.00539017]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 3: [-46.47661]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.04082108]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 4: [-46.470642]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.04678726]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling random 1 -- Mean LogLH Bootstrap: -46.5195 ±  0.0593
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -46.51742935180664

# %%
print('Results based on test data' + '\n')
cur_res = 'test' 

test_data = dataset.get_test_data()
mean_target = torch.mean(dataset.evaluate(test_data)).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(test_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))

# for flow in best_flows:
#     log_lik, mean = log_likelihood(test_data, flow)
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
    

# print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on test data
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 0: [-46.809696]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.47486877]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 1: [-46.894444]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.5596161]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 2: [-46.877537]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.54270935]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 3: [-46.944313]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.6094856]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 4: [-46.95142]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.6165924]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling identity 1 -- Mean LogLH Bootstrap: -46.8955 ±  0.0713
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 0: [-46.872353]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.5375252]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 1: [-46.836536]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.501709]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 2: [-46.95574]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.62091446]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 3: [-46.881783]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.5469551]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 4: [-46.908627]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.57379913]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling alternate 1 -- Mean LogLH Bootstrap: -46.8910 ±  0.0552
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 0: [-46.842445]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.50761795]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 1: [-46.82868]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.4938507]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 2: [-46.83111]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.49628067]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 3: [-46.86236]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.52753067]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 4: [-46.76801]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.43318176]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling random 1 -- Mean LogLH Bootstrap: -46.8265 ±  0.0438
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -46.3348274230957

# %%
print('Results based on new sample from each flow:' + '\n')
cur_res = 'sample'

for flow in best_flows:
    for i in range(num_exp):
        with torch.no_grad():
            sample, log_prob = flows[flow][i].sample(800)
            sample_last = sample[-1]

        mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
        log_lik, mean = log_likelihood(sample_last, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print("Mean loglikelihood with actual distribution: {}".format(mean_target))   
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()


# for flow in best_flows:
#     with torch.no_grad():
#         sample, log_prob = flow.sample(800)
#         sample_last = sample[-1]

#     #sample_last.clip_(-7, 7)
#     mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
#     log_lik, mean = log_likelihood(sample_last, flow)

#     print('Check for NANs: ', torch.isnan(sample_last).any().item())
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))    
#     print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on new sample from each flow:
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 0: [-46.689003]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.51758957]
# Mean loglikelihood with actual distribution: -47.20659255981445
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 1: [-46.55376]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.49430466]
# Mean loglikelihood with actual distribution: -47.048065185546875
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 2: [-46.431416]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.5358505]
# Mean loglikelihood with actual distribution: -46.96726608276367
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 3: [-46.651928]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.6023598]
# Mean loglikelihood with actual distribution: -47.25428771972656
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling identity 1 4: [-46.238888]
# Difference between target and ContinuousPiecewiseAffineAffine coupling identity 1 mean loglikelihood: [0.458313]
# Mean loglikelihood with actual distribution: -46.697200775146484
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling identity 1 -- Mean LogLH Bootstrap: -46.5130 ±  0.2270
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 0: [-46.660057]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.5006752]
# Mean loglikelihood with actual distribution: -47.16073226928711
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 1: [-47.09131]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.53585815]
# Mean loglikelihood with actual distribution: -47.627166748046875
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 2: [-46.686535]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.64185715]
# Mean loglikelihood with actual distribution: -47.328392028808594
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 3: [-46.89412]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.48348236]
# Mean loglikelihood with actual distribution: -47.377601623535156
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling alternate 1 4: [-46.73587]
# Difference between target and ContinuousPiecewiseAffineAffine coupling alternate 1 mean loglikelihood: [0.5793495]
# Mean loglikelihood with actual distribution: -47.31521987915039
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling alternate 1 -- Mean LogLH Bootstrap: -46.8136 ±  0.2233
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 0: [-47.192207]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.5027199]
# Mean loglikelihood with actual distribution: -47.69492721557617
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 1: [-46.261417]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.50460434]
# Mean loglikelihood with actual distribution: -46.766021728515625
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 2: [-46.31654]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.5241394]
# Mean loglikelihood with actual distribution: -46.84067916870117
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 3: [-46.789516]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.58218384]
# Mean loglikelihood with actual distribution: -47.371700286865234
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine coupling random 1 4: [-46.904476]
# Difference between target and ContinuousPiecewiseAffineAffine coupling random 1 mean loglikelihood: [0.43727112]
# Mean loglikelihood with actual distribution: -47.34174728393555
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine coupling random 1 -- Mean LogLH Bootstrap: -46.6928 ±  0.4933
# ---------------------------------------------------------------------------
