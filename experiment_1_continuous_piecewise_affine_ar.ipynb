# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import os

import numpy as np
import matplotlib.pyplot as plt

from NormalizingFlows.src.train import train_backward
from NormalizingFlows.src.scores import log_likelihood
from NormalizingFlows.src.utils import update_device, load_best_model, load_checkpoint_model

from NormalizingFlows.src.flows import *
from NormalizingFlows.src.data.density.toydata import ToyDataset

# %%
def set_visible_devices(*devices: int) -> None:
    '''Utility to set visible Cuda devices.

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.
    '''
    assert all([d >= 0 for d in devices]), f"Not all devices are CUDA devices!"
    os.environ['CUDA_VISIBLE_DEVICES'] = ",".join([str(i) for i in devices])
    

def set_devices(*devices: int):
    '''Utility to set Cuda device(s).

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.

    Returns
    -------
    torch.device or List[torch.device] of currently available CUDA devices.
    '''
    assert len(devices) > 0, f'Device list is empty, no devices set.'
    if len(devices) == 1:
        if devices[0] >= 0:
            set_visible_devices(devices[0])
            return torch.device(0)
        else:
            return torch.device('cpu')

    else:
        set_visible_devices(*devices)
        return [torch.device(i) for i in range(len(devices))]

# %%
device = set_devices(0) #torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device_cpu = torch.device("cpu")

# %%
dim_input = 25
dataset = ToyDataset(dim_input=dim_input, samples=10000)

dim_input = dataset.dim_input
num_trans = 6 #Must be even
perm_types = ['identity', 'alternate','random']
dim_hidden = [100,100,100]
flows = {}
flow_forward = False


epochs = 15
batch_size = 32
num_exp = 5

# %%
# #Linear and mean field

# transformations = create_constant_trans(num_trans, dim_input, flow_forward)
# mean_field = create_flows_with_identity(dim_input, transformations, flow_forward) 
# name = 'Mean field'
# flows.append(mean_field), names.append(name)

# transformations = create_linear_bias_trans(num_trans, dim_input, flow_forward)
# linear = create_flows_with_identity(dim_input, transformations, flow_forward)
# name = 'Linear'
# flows.append(linear), names.append(name);

# %%
# #Affine flows with two block

# name = 'Affine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine coupling alternating'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_coup_alt]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'Affine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Affine flows with AR

# name = 'Affine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with coupling

# name = 'PiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_coup_id]
#     flows[name][-1].name = f'{name} {i}'
    

# name = 'PiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with AR

# name = 'PiecewiseAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_ar_id]
#     flows[name][-1].name = f'{name} {i}'


# name = 'PiecewiseAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with twoblock

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with AR

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with twoblock

# name = 'ContinuousPiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [conpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [conpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [conpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with AR

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'ContinuousPiecewiseAffine AR identity'
# flows.append(conpiec_ar_iden), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
# name = 'ContinuousPiecewiseAffine AR alternate'
# flows.append(conpiec_ar_alt), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'ContinuousPiecewiseAffine AR random'
# flows.append(conpiec_ar_rand), names.append(name);

# %%
# #ContinuousPiecewiseAffine with twoblock
# name = 'ContinuousPiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [affconpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'ContinuousPiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [affconpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [affconpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
#ContinuousPiecewiseAffine with AR
name = 'ContinuousPiecewiseAffineAffine AR identity 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_affinecontinuous_trans(num_trans, flow_forward)
    affconpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
    flows[name] += [affconpiec_ar_iden]
    flows[name][-1].name = f'{name} {i}'

name = 'ContinuousPiecewiseAffineAffine AR alternate 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_affinecontinuous_trans(num_trans, flow_forward)
    affconpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
    flows[name] += [affconpiec_ar_alt]
    flows[name][-1].name = f'{name} {i}'

name = 'ContinuousPiecewiseAffineAffine AR random 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_affinecontinuous_trans(num_trans, flow_forward)
    affconpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [affconpiec_ar_rand]
    flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating Piecewise Affine with twoblock

# transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
# afpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Affin_PiecewiseAffine coupling random'
# flows.append(afpiec_coup_rand), names.append(name);

# %%
# #Alternating Piecewise Affine with AR

# transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
# afpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Affin_PiecewiseAffine AR random'
# flows.append(afpiec_ar_rand), names.append(name);

# %%
# #Alternating with Linear layer and Affine

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'Alternating Linear_Affine coupling identity'
# flows.append(linaff_coup_iden), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_Affine coupling random'
# flows.append(linaff_coup_rand), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'Alternating Linear_Affine AR identity'
# flows.append(linaff_ar_iden), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_Affine AR random'
# flows.append(linaff_ar_rand), names.append(name);

# %%
# #Various Alternating Linear and Conditioner transformation

# transformations = create_alt_linear_piecewise_trans(num_trans, dim_input, flow_forward)
# linpiece_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_PiecewiseAffine coupling random'
# flows.append(linpiece_coup_rand), names.append(name)

# transformations = create_alt_linear_continuous_trans(num_trans, dim_input, flow_forward)
# lincont_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_ContinuousPiece coupling random'
# flows.append(lincont_coup_rand), names.append(name)

# transformations = create_alt_linear_affinepiecewise_trans(num_trans, dim_input, flow_forward)
# linaffpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_AffinePiece coupling random'
# flows.append(linaffpiec_coup_rand), names.append(name)

# transformations = create_alt_linear_affinecontinuous_trans(num_trans, dim_input, flow_forward)
# linaffcont_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_AffineContinuous coupling random'
# flows.append(linaffcont_coup_rand), names.append(name);

# %%
losses = {n: [] for n in flows.keys()}
optimizers = {n: [] for n in flows.keys()}

for flowname in flows.keys():
    for j in range(num_exp):
        # Initialize flow
        flow = flows[flowname][j]
        update_device(device, flow, dataset)

        # Initialize optimizer
        optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-4, weight_decay=1e-2)
        optimizers[flowname].append(optimizer)
        
        # Train and append losses
        losses[flowname].append(
            train_backward(
                flow, 
                dataset.get_training_data(), 
                optimizer, 
                epochs - 7, 
                batch_size, 
                print_n=200, 
                save_checkpoint=True, 
                burn_in=-1
            )
        )

        # Move flow to CPU
        update_device(device_cpu, flow, dataset)
# Out:
# Finished training. Loss for last epoch ContinuousPiecewiseAffineAffine AR random 1 4:     46.71644

# %%
best_flows = {n:[] for n in flows.keys()}
for flowname in flows.keys():
    for i in range(num_exp):
        best_flows[flowname].append(load_best_model(flows[flowname][i]))

# %%
log_scale = True
from_iter = 50 * batch_size

fig, ax = plt.subplots(2, len(flows), figsize=(12,6))
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        ax[0,j].plot(losses[flowname][i], label=f'exp{i}', alpha=0.8)
        ax[0,j].set_title(f'{flowname}')
        if log_scale:
            ax[0, j].set_yscale('log')
        ax[0, j].legend()
        
log_scale = True
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        x = np.arange(len(losses[flowname][i]))
        ax[1,j].plot(x[from_iter:], losses[flowname][i][from_iter:], label=f'exp{i}', alpha=0.8)
        if log_scale:
            ax[1, j].set_yscale('log')
        ax[1, j].legend()
    
plt.tight_layout()

# %%
flow_lh_results = {
    'train': {n:[] for n in flows}, 
    'test': {n:[] for n in flows}, 
    'sample': {n:[] for n in flows},
}
cur_res = 'train'

print('Results based on training data:' + '\n')

# Function for CI
def mean_confidence_interval(data, confidence=0.95):
    import scipy.stats
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, h
 

train_data = dataset.get_training_data()
mean_target = torch.mean(dataset.evaluate(train_data.to(device))).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(train_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on training data:
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 0: [-47.310757]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.91975784]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 1: [-47.19668]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.8056793]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 2: [-47.15856]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.76756287]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 3: [-47.307133]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.9161339]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 4: [-47.294086]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.9030876]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR identity 1 -- Mean LogLH Bootstrap: -47.2534 ±  0.0879
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 0: [-46.743946]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.35294724]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 1: [-46.749092]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.35809326]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 2: [-46.723965]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.33296585]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 3: [-46.70646]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.3154602]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 4: [-46.75803]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.3670311]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR alternate 1 -- Mean LogLH Bootstrap: -46.7363 ±  0.0259
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 0: [-46.6302]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.23920059]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 1: [-46.662243]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.27124405]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 2: [-46.658264]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.26726532]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 3: [-46.664417]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.27341843]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 4: [-46.657074]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.26607513]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR random 1 -- Mean LogLH Bootstrap: -46.6544 ±  0.0172
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -46.39099884033203

# %%
print('Results based on test data' + '\n')
cur_res = 'test' 

test_data = dataset.get_test_data()
mean_target = torch.mean(dataset.evaluate(test_data)).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(test_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))

# for flow in best_flows:
#     log_lik, mean = log_likelihood(test_data, flow)
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
    

# print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on test data
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 0: [-47.41478]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.9622688]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 1: [-47.327118]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.8746071]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 2: [-47.294445]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.8419342]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 3: [-47.443214]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.9907036]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 4: [-47.39049]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [0.93798065]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR identity 1 -- Mean LogLH Bootstrap: -47.3740 ±  0.0767
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 0: [-46.87218]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.4196701]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 1: [-46.86836]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.41584778]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 2: [-46.847897]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.39538574]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 3: [-46.865257]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.41274643]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 4: [-46.897026]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.44451523]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR alternate 1 -- Mean LogLH Bootstrap: -46.8701 ±  0.0219
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 0: [-46.780453]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.3279419]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 1: [-46.80856]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.35604858]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 2: [-46.812286]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.35977554]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 3: [-46.794155]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.3416443]
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 4: [-46.817223]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.36471176]
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR random 1 -- Mean LogLH Bootstrap: -46.8025 ±  0.0187
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -46.452510833740234

# %%
print('Results based on new sample from each flow:' + '\n')
cur_res = 'sample'

for flow in best_flows:
    for i in range(num_exp):
        with torch.no_grad():
            sample, log_prob = flows[flow][i].sample(800)
            sample_last = sample[-1]

        mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
        log_lik, mean = log_likelihood(sample_last, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print("Mean loglikelihood with actual distribution: {}".format(mean_target))   
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()


# for flow in best_flows:
#     with torch.no_grad():
#         sample, log_prob = flow.sample(800)
#         sample_last = sample[-1]

#     #sample_last.clip_(-7, 7)
#     mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
#     log_lik, mean = log_likelihood(sample_last, flow)

#     print('Check for NANs: ', torch.isnan(sample_last).any().item())
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))    
#     print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on new sample from each flow:
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 0: [-46.427868]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [3.233879]
# Mean loglikelihood with actual distribution: -49.661746978759766
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 1: [-46.696358]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [2.0047646]
# Mean loglikelihood with actual distribution: -48.70112228393555
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 2: [-47.008324]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [1.996006]
# Mean loglikelihood with actual distribution: -49.004329681396484
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 3: [-47.156105]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [2.3781242]
# Mean loglikelihood with actual distribution: -49.53422927856445
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR identity 1 4: [-46.685272]
# Difference between target and ContinuousPiecewiseAffineAffine AR identity 1 mean loglikelihood: [2.783123]
# Mean loglikelihood with actual distribution: -49.4683952331543
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR identity 1 -- Mean LogLH Bootstrap: -46.7948 ±  0.3580
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 0: [-46.33088]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.3495102]
# Mean loglikelihood with actual distribution: -46.680389404296875
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 1: [-46.475826]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.36253738]
# Mean loglikelihood with actual distribution: -46.83836364746094
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 2: [-46.76716]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.3654251]
# Mean loglikelihood with actual distribution: -47.13258361816406
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 3: [-46.8892]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.42066193]
# Mean loglikelihood with actual distribution: -47.30986022949219
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR alternate 1 4: [-46.81175]
# Difference between target and ContinuousPiecewiseAffineAffine AR alternate 1 mean loglikelihood: [0.42734146]
# Mean loglikelihood with actual distribution: -47.23908996582031
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR alternate 1 -- Mean LogLH Bootstrap: -46.6550 ±  0.2972
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 0: [-46.773453]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.40489578]
# Mean loglikelihood with actual distribution: -47.178348541259766
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 1: [-46.824883]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.30480957]
# Mean loglikelihood with actual distribution: -47.12969207763672
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 2: [-47.002453]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.40384674]
# Mean loglikelihood with actual distribution: -47.40629959106445
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 3: [-46.403847]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.33618164]
# Mean loglikelihood with actual distribution: -46.740028381347656
#
# Mean loglikelihood for ContinuousPiecewiseAffineAffine AR random 1 4: [-46.95917]
# Difference between target and ContinuousPiecewiseAffineAffine AR random 1 mean loglikelihood: [0.32194138]
# Mean loglikelihood with actual distribution: -47.28111267089844
#
# ---------------------------------------------------------------------------
# ContinuousPiecewiseAffineAffine AR random 1 -- Mean LogLH Bootstrap: -46.7928 ±  0.2940
# ---------------------------------------------------------------------------
