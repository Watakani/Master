# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import os

import numpy as np
import matplotlib.pyplot as plt

from NormalizingFlows.src.train import train_backward
from NormalizingFlows.src.scores import log_likelihood
from NormalizingFlows.src.utils import update_device, load_best_model, load_checkpoint_model

from NormalizingFlows.src.flows import *
from NormalizingFlows.src.data.density.toydata import ToyDataset

# %%
def set_visible_devices(*devices: int) -> None:
    '''Utility to set visible Cuda devices.

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.
    '''
    assert all([d >= 0 for d in devices]), f"Not all devices are CUDA devices!"
    os.environ['CUDA_VISIBLE_DEVICES'] = ",".join([str(i) for i in devices])
    

def set_devices(*devices: int):
    '''Utility to set Cuda device(s).

    Parameters
    ----------
    devices : List[int]
        Index of cuda devices to make available for use.

    Returns
    -------
    torch.device or List[torch.device] of currently available CUDA devices.
    '''
    assert len(devices) > 0, f'Device list is empty, no devices set.'
    if len(devices) == 1:
        if devices[0] >= 0:
            set_visible_devices(devices[0])
            return torch.device(0)
        else:
            return torch.device('cpu')

    else:
        set_visible_devices(*devices)
        return [torch.device(i) for i in range(len(devices))]

# %%
device = set_devices(0) #torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device_cpu = torch.device("cpu")

# %%
dim_input = 25
dataset = ToyDataset(dim_input=dim_input, samples=10000)

dim_input = dataset.dim_input
num_trans = 6 #Must be even
perm_types = ['identity', 'alternate','random']
dim_hidden = [100,100,100]
flows = {}
flow_forward = False


epochs = 15
batch_size = 32
num_exp = 5

# %%
# #Linear and mean field

# transformations = create_constant_trans(num_trans, dim_input, flow_forward)
# mean_field = create_flows_with_identity(dim_input, transformations, flow_forward) 
# name = 'Mean field'
# flows.append(mean_field), names.append(name)

# transformations = create_linear_bias_trans(num_trans, dim_input, flow_forward)
# linear = create_flows_with_identity(dim_input, transformations, flow_forward)
# name = 'Linear'
# flows.append(linear), names.append(name);

# %%
# #Affine flows with two block

# name = 'Affine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine coupling alternating'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_coup_alt]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'Affine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward, a_param=F.softplus)
#     aff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Affine flows with AR

# name = 'Affine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [aff_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [aff_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'Affine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affine_trans(num_trans, flow_forward)
#     aff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [aff_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with coupling

# name = 'PiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_coup_id]
#     flows[name][-1].name = f'{name} {i}'
    

# name = 'PiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffine flows with AR

# name = 'PiecewiseAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piec_ar_id]
#     flows[name][-1].name = f'{name} {i}'


# name = 'PiecewiseAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piec_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_piecewise_trans(num_trans, flow_forward)
#     piec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with twoblock

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_id = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_coup_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #PiecewiseAffineAffine with AR

# kwargs = {
#     'a_param' : F.sigmoid,
#     'c_param' : F.sigmoid,
# }

# name = 'PiecewiseAffineAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_id = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [piecaf_ar_id]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward)
#     piecaf_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [piecaf_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'PiecewiseAffineAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinepiecewise_trans(num_trans, flow_forward, **kwargs)
#     piecaf_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [piecaf_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with twoblock

# name = 'ContinuousPiecewiseAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [conpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [conpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
#     conpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [conpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewise with AR

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'ContinuousPiecewiseAffine AR identity'
# flows.append(conpiec_ar_iden), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
# name = 'ContinuousPiecewiseAffine AR alternate'
# flows.append(conpiec_ar_alt), names.append(name)

# transformations = create_continuous_piecewise_trans(num_trans, flow_forward)
# conpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'ContinuousPiecewiseAffine AR random'
# flows.append(conpiec_ar_rand), names.append(name);

# %%
# #ContinuousPiecewiseAffine with twoblock
# name = 'ContinuousPiecewiseAffineAffine coupling identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [affconpiec_coup_iden]
#     flows[name][-1].name = f'{name} {i}'
    
# name = 'ContinuousPiecewiseAffineAffine coupling alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_alt = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [affconpiec_coup_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [affconpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #ContinuousPiecewiseAffine with AR
# name = 'ContinuousPiecewiseAffineAffine AR identity'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
#     flows[name] += [affconpiec_ar_iden]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine AR alternate'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_alt = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[1], flow_forward)
#     flows[name] += [affconpiec_ar_alt]
#     flows[name][-1].name = f'{name} {i}'

# name = 'ContinuousPiecewiseAffineAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_affinecontinuous_trans(num_trans, flow_forward)
#     affconpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [affconpiec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating Piecewise Affine with twoblock

# name = 'Alternating Affin_PiecewiseAffine coupling random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
#     afpiec_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [afpiec_coup_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating Piecewise Affine with AR

# name = 'Alternating Affin_PiecewiseAffine AR random'
# flows[name] = []
# for i in range(num_exp):
#     transformations = create_alt_piecewise_affine_trans(num_trans, flow_forward)
#     afpiec_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
#     flows[name] += [afpiec_ar_rand]
#     flows[name][-1].name = f'{name} {i}'

# %%
# #Alternating with Linear layer and Affine

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_coup_iden = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'Alternating Linear_Affine coupling identity'
# flows.append(linaff_coup_iden), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_coup_rand = create_flows_with_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_Affine coupling random'
# flows.append(linaff_coup_rand), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_ar_iden = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[0], flow_forward)
# name = 'Alternating Linear_Affine AR identity'
# flows.append(linaff_ar_iden), names.append(name)

# transformations = create_alt_linear_affine_trans(num_trans, dim_input, flow_forward)
# linaff_ar_rand = create_flows_with_AR(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
# name = 'Alternating Linear_Affine AR random'
# flows.append(linaff_ar_rand), names.append(name);

# %%
#Various Alternating Linear and Conditioner transformation

name = 'Alternating Linear_PiecewiseAffine coupling random 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_piecewise_trans(num_trans, dim_input, flow_forward)
    linpiece_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [linpiece_coup_rand]
    flows[name][-1].name = f'{name} {i}'

name = 'Alternating Linear_ContinuousPiece coupling random 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_continuous_trans(num_trans, dim_input, flow_forward)
    lincont_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [lincont_coup_rand]
    flows[name][-1].name = f'{name} {i}'

name = 'Alternating Linear_AffinePiece coupling random 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_affinepiecewise_trans(num_trans, dim_input, flow_forward)
    linaffpiec_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [linaffpiec_coup_rand]
    flows[name][-1].name = f'{name} {i}'

name = 'Alternating Linear_AffineContinuous coupling random 1'
flows[name] = []
for i in range(num_exp):
    transformations = create_alt_linear_affinecontinuous_trans(num_trans, dim_input, flow_forward)
    linaffcont_coup_rand = create_flows_with_alt_identity_twoblock(dim_input, dim_hidden, transformations, perm_types[2], flow_forward)
    flows[name] += [linaffcont_coup_rand]
    flows[name][-1].name = f'{name} {i}'

# %%
losses = {n: [] for n in flows.keys()}
optimizers = {n: [] for n in flows.keys()}

for flowname in flows.keys():
    for j in range(num_exp):
        # Initialize flow
        flow = flows[flowname][j]
        update_device(device, flow, dataset)

        # Initialize optimizer
        optimizer = torch.optim.AdamW(flow.parameters(), lr=1e-4, weight_decay=1e-2)
        optimizers[flowname].append(optimizer)
        
        # Train and append losses
        losses[flowname].append(
            train_backward(
                flow, 
                dataset.get_training_data(), 
                optimizer, 
                epochs - 7, 
                batch_size, 
                print_n=200, 
                save_checkpoint=True, 
                burn_in=-1
            )
        )

        # Move flow to CPU
        update_device(device_cpu, flow, dataset)
# Out:
# Finished training. Loss for last epoch Alternating Linear_AffineContinuous coupling random 1 4:     46.59293

# %%
best_flows = {n:[] for n in flows.keys()}
for flowname in flows.keys():
    for i in range(num_exp):
        best_flows[flowname].append(load_best_model(flows[flowname][i]))

# %%
log_scale = True
from_iter = 50 * batch_size

fig, ax = plt.subplots(2, len(flows), figsize=(12,6))
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        ax[0,j].plot(losses[flowname][i], label=f'exp{i}', alpha=0.8)
        ax[0,j].set_title(f'{flowname}')
        if log_scale:
            ax[0, j].set_yscale('log')
        ax[0, j].legend()
        
log_scale = True
for j, flowname in enumerate(flows.keys()):
    for i in range(num_exp):
        x = np.arange(len(losses[flowname][i]))
        ax[1,j].plot(x[from_iter:], losses[flowname][i][from_iter:], label=f'exp{i}', alpha=0.8)
        if log_scale:
            ax[1, j].set_yscale('log')
        ax[1, j].legend()
    
plt.tight_layout()

# %%
flow_lh_results = {
    'train': {n:[] for n in flows}, 
    'test': {n:[] for n in flows}, 
    'sample': {n:[] for n in flows},
}
cur_res = 'train'

print('Results based on training data:' + '\n')

# Function for CI
def mean_confidence_interval(data, confidence=0.95):
    import scipy.stats
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, h
 

train_data = dataset.get_training_data()
mean_target = torch.mean(dataset.evaluate(train_data.to(device))).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(train_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on training data:
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 0: [-46.80332]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.33542633]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 1: [-46.684345]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.21644974]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 2: [-46.74972]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.28182602]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 3: [-46.824768]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.35687256]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 4: [-46.801]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.33310318]
#
# ---------------------------------------------------------------------------
# Alternating Linear_PiecewiseAffine coupling random 1 -- Mean LogLH Bootstrap: -46.7726 ±  0.0702
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 0: [-47.24957]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [0.78167343]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 1: [-47.32125]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [0.8533554]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 2: [-47.355564]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [0.8876686]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 3: [-47.288944]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [0.82104874]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 4: [-47.428577]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [0.9606819]
#
# ---------------------------------------------------------------------------
# Alternating Linear_ContinuousPiece coupling random 1 -- Mean LogLH Bootstrap: -47.3288 ±  0.0847
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 0: [-46.65784]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.18994522]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 1: [-46.659973]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.19207764]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 2: [-46.67673]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.2088356]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 3: [-46.588478]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.12058258]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 4: [-46.62039]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.15249634]
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffinePiece coupling random 1 -- Mean LogLH Bootstrap: -46.6407 ±  0.0443
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 0: [-46.491463]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.0235672]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 1: [-46.52392]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.05602264]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 2: [-46.525555]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.05765915]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 3: [-46.466087]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.00180817]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 4: [-46.52283]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.05493546]
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffineContinuous coupling random 1 -- Mean LogLH Bootstrap: -46.5060 ±  0.0328
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -46.4678955078125

# %%
print('Results based on test data' + '\n')
cur_res = 'test' 

test_data = dataset.get_test_data()
mean_target = torch.mean(dataset.evaluate(test_data)).detach().numpy()
for flow in best_flows:
    for i in range(num_exp):
        log_lik, mean = log_likelihood(test_data, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()
    

print("Mean loglikelihood with actual distribution: {}".format(mean_target))

# for flow in best_flows:
#     log_lik, mean = log_likelihood(test_data, flow)
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
    

# print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on test data
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 0: [-47.147503]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.54761124]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 1: [-46.999973]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.40008163]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 2: [-47.049652]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.44976044]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 3: [-47.075573]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.4756813]
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 4: [-47.110672]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.51078033]
#
# ---------------------------------------------------------------------------
# Alternating Linear_PiecewiseAffine coupling random 1 -- Mean LogLH Bootstrap: -47.0767 ±  0.0702
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 0: [-47.49092]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [0.89102936]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 1: [-47.59108]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [0.99118805]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 2: [-47.629406]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [1.0295143]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 3: [-47.52076]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [0.9208679]
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 4: [-47.75462]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [1.1547279]
#
# ---------------------------------------------------------------------------
# Alternating Linear_ContinuousPiece coupling random 1 -- Mean LogLH Bootstrap: -47.5974 ±  0.1287
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 0: [-47.03989]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.43999863]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 1: [-47.096783]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.49689102]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 2: [-47.063374]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.4634819]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 3: [-46.95964]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.35974884]
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 4: [-47.002525]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.40263367]
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffinePiece coupling random 1 -- Mean LogLH Bootstrap: -47.0324 ±  0.0661
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 0: [-46.9042]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.30430984]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 1: [-46.879353]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.2794609]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 2: [-46.93557]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.3356781]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 3: [-46.883102]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.28321075]
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 4: [-46.91685]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.31695938]
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffineContinuous coupling random 1 -- Mean LogLH Bootstrap: -46.9038 ±  0.0292
# ---------------------------------------------------------------------------
#
# Mean loglikelihood with actual distribution: -46.599891662597656

# %%
print('Results based on new sample from each flow:' + '\n')
cur_res = 'sample'

for flow in best_flows:
    for i in range(num_exp):
        with torch.no_grad():
            sample, log_prob = flows[flow][i].sample(800)
            sample_last = sample[-1]

        mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
        log_lik, mean = log_likelihood(sample_last, flows[flow][i])
        flow_lh_results[cur_res][flow].append(mean[0])
        print("Mean loglikelihood for {}: {}".format(f'{flow} {i}', mean))
        print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))
        print("Mean loglikelihood with actual distribution: {}".format(mean_target))   
        print()
    
    m, h = mean_confidence_interval(flow_lh_results[cur_res][flow])
    print('-'*75)
    print(f'{flow} -- Mean LogLH Bootstrap: {m:7.4f} ± {h:7.4f}')
    print('-'*75)
    print()


# for flow in best_flows:
#     with torch.no_grad():
#         sample, log_prob = flow.sample(800)
#         sample_last = sample[-1]

#     #sample_last.clip_(-7, 7)
#     mean_target = torch.mean(dataset.evaluate(sample_last)).detach().numpy()
#     log_lik, mean = log_likelihood(sample_last, flow)

#     print('Check for NANs: ', torch.isnan(sample_last).any().item())
#     print("Mean loglikelihood for {}: {}".format(str(flow), mean))
#     print("Difference between target and {} mean loglikelihood: {}".format(str(flow), abs(mean-mean_target)))    
#     print("Mean loglikelihood with actual distribution: {}".format(mean_target))
# Out:
# Results based on new sample from each flow:
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 0: [-47.374657]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.5920372]
# Mean loglikelihood with actual distribution: -47.96669387817383
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 1: [-46.797394]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.4699211]
# Mean loglikelihood with actual distribution: -47.26731491088867
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 2: [-47.068947]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.58509445]
# Mean loglikelihood with actual distribution: -47.6540412902832
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 3: [-47.43578]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.5312462]
# Mean loglikelihood with actual distribution: -47.96702575683594
#
# Mean loglikelihood for Alternating Linear_PiecewiseAffine coupling random 1 4: [-47.198082]
# Difference between target and Alternating Linear_PiecewiseAffine coupling random 1 mean loglikelihood: [0.6665535]
# Mean loglikelihood with actual distribution: -47.8646354675293
#
# ---------------------------------------------------------------------------
# Alternating Linear_PiecewiseAffine coupling random 1 -- Mean LogLH Bootstrap: -47.1750 ±  0.3179
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 0: [-47.3859]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [2.6808891]
# Mean loglikelihood with actual distribution: -50.06678771972656
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 1: [-47.47789]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [3.1913147]
# Mean loglikelihood with actual distribution: -50.66920471191406
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 2: [-47.358273]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [3.356594]
# Mean loglikelihood with actual distribution: -50.714866638183594
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 3: [-47.092518]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [2.7930527]
# Mean loglikelihood with actual distribution: -49.88557052612305
#
# Mean loglikelihood for Alternating Linear_ContinuousPiece coupling random 1 4: [-47.33752]
# Difference between target and Alternating Linear_ContinuousPiece coupling random 1 mean loglikelihood: [2.3232994]
# Mean loglikelihood with actual distribution: -49.66082000732422
#
# ---------------------------------------------------------------------------
# Alternating Linear_ContinuousPiece coupling random 1 -- Mean LogLH Bootstrap: -47.3304 ±  0.1780
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 0: [-46.8405]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.49227524]
# Mean loglikelihood with actual distribution: -47.3327751159668
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 1: [-46.858936]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.43519974]
# Mean loglikelihood with actual distribution: -47.29413604736328
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 2: [-46.831017]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.46578598]
# Mean loglikelihood with actual distribution: -47.29680252075195
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 3: [-47.26562]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.41212463]
# Mean loglikelihood with actual distribution: -47.6777458190918
#
# Mean loglikelihood for Alternating Linear_AffinePiece coupling random 1 4: [-46.38458]
# Difference between target and Alternating Linear_AffinePiece coupling random 1 mean loglikelihood: [0.402565]
# Mean loglikelihood with actual distribution: -46.78714370727539
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffinePiece coupling random 1 -- Mean LogLH Bootstrap: -46.8361 ±  0.3872
# ---------------------------------------------------------------------------
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 0: [-46.48267]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.28979492]
# Mean loglikelihood with actual distribution: -46.772464752197266
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 1: [-46.746593]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.29471588]
# Mean loglikelihood with actual distribution: -47.04130935668945
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 2: [-46.58379]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.35165787]
# Mean loglikelihood with actual distribution: -46.935447692871094
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 3: [-46.596176]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.2804451]
# Mean loglikelihood with actual distribution: -46.87662124633789
#
# Mean loglikelihood for Alternating Linear_AffineContinuous coupling random 1 4: [-46.885277]
# Difference between target and Alternating Linear_AffineContinuous coupling random 1 mean loglikelihood: [0.27915573]
# Mean loglikelihood with actual distribution: -47.164432525634766
#
# ---------------------------------------------------------------------------
# Alternating Linear_AffineContinuous coupling random 1 -- Mean LogLH Bootstrap: -46.6589 ±  0.1959
# ---------------------------------------------------------------------------
